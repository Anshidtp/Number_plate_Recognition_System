# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'e:\\Projects\\Number_plate_Recognition_System\\Research'

# %%
cd ../
# Out:
# e:\Projects\Number_plate_Recognition_System

# %%
image = cv2.imread('Sample_Data\pupy1.jpg')

# %%
image.shape
# Out:
# (612, 407, 3)

# %%
cv2.imshow("puppy",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Resize image
resized_image = cv2.resize(image,(300,300))

# %%
resized_image.shape
# Out:
# (300, 300, 3)

# %%
#crop image
croped_image = image[50:250,100:150]

# %%
cv2.imshow("croped_image",croped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#rotate image
(h,w) = image.shape[:2]

# %%
rotete_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)

# %%
cv2.imshow("rotete_image",rotete_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
 #edge detection
 import matplotlib.pyplot as plt
 def show(img):
     plt.imshow(img,cmap='gray')
     plt.axis('off')
     plt.show()

# %%
show(image)

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
show(gray)

# %%
sobelX = cv2.Sobel(gray,cv2.CV_64F,1,0,ksize=5)
show(sobelX)

# %%
sobelY = cv2.Sobel(gray,cv2.CV_64F,0,1,ksize=5)
show(sobelY)

# %%
canny = cv2.Canny(gray,100,150)
show(canny)

# %%
laplacian = cv2.Laplacian(gray,cv2.CV_64F)
show(laplacian)
